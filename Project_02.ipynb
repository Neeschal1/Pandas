# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeschal1/Pandas/blob/main/Project_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Learning_Pandas/Projects/Project_02/readme.csv")
df
# Out:
#                        Movie      Genre  Year  Rating
# 0                   3 Idiots     Comedy  2009     8.4
# 1                     Dangal      Drama  2016     8.4
# 2                         PK     Comedy  2014     8.1
# 3                     Lagaan     Sports  2001     8.1
# 4           Taare Zameen Par      Drama  2007     8.4
# ..                       ...        ...   ...     ...
# 62  The Grand Budapest Hotel     Comedy  2014     8.1
# 63       Slumdog Millionaire      Drama  2008     8.0
# 64              The Revenant  Adventure  2015     8.0
# 65                   Gravity     Sci-Fi  2013     7.7
# 66                La La Land    Musical  2016     8.0
#
# [67 rows x 4 columns]

# %%
high_rating = df[df["Rating"] > 7.0]
high_rating
# Out:
#                        Movie      Genre  Year  Rating
# 0                   3 Idiots     Comedy  2009     8.4
# 1                     Dangal      Drama  2016     8.4
# 2                         PK     Comedy  2014     8.1
# 3                     Lagaan     Sports  2001     8.1
# 4           Taare Zameen Par      Drama  2007     8.4
# ..                       ...        ...   ...     ...
# 62  The Grand Budapest Hotel     Comedy  2014     8.1
# 63       Slumdog Millionaire      Drama  2008     8.0
# 64              The Revenant  Adventure  2015     8.0
# 65                   Gravity     Sci-Fi  2013     7.7
# 66                La La Land    Musical  2016     8.0
#
# [67 rows x 4 columns]

# %%
low_rating = df[df["Rating"] < 8]
low_rating
# Out:
#                  Movie   Genre  Year  Rating
# 53            Iron Man  Action  2008     7.9
# 60  The Social Network   Drama  2010     7.7
# 65             Gravity  Sci-Fi  2013     7.7

# %% [markdown]
# # Understanding ILOC and LOC

# %%
data = df.iloc[1:20:3, :3]
data
# Out:
#                        Movie     Genre  Year
# 1                     Dangal     Drama  2016
# 4           Taare Zameen Par     Drama  2007
# 7                   Drishyam  Thriller  2015
# 10                 Gully Boy     Drama  2019
# 13  Zindagi Na Milegi Dobara     Drama  2011
# 16  The Shawshank Redemption     Drama  1994
# 19              Pulp Fiction     Crime  1994

# %%
dta = df.loc[1:30:4, "Movie":"Year"]
dta
# Out:
#                        Movie      Genre  Year
# 1                     Dangal      Drama  2016
# 5          Bajrangi Bhaijaan      Drama  2015
# 9                     Barfi!    Romance  2012
# 13  Zindagi Na Milegi Dobara      Drama  2011
# 17             The Godfather      Crime  1972
# 21              Forrest Gump      Drama  1994
# 25                Goodfellas      Crime  1990
# 29             Spirited Away  Animation  2001
