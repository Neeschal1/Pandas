# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeschal1/Pandas/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Learning_Pandas/Projects/Project_02/readme.csv")
df
# Out:
#                        Movie      Genre  Year  Rating
# 0                   3 Idiots     Comedy  2009     8.4
# 1                     Dangal      Drama  2016     8.4
# 2                         PK     Comedy  2014     8.1
# 3                     Lagaan     Sports  2001     8.1
# 4           Taare Zameen Par      Drama  2007     8.4
# ..                       ...        ...   ...     ...
# 62  The Grand Budapest Hotel     Comedy  2014     8.1
# 63       Slumdog Millionaire      Drama  2008     8.0
# 64              The Revenant  Adventure  2015     8.0
# 65                   Gravity     Sci-Fi  2013     7.7
# 66                La La Land    Musical  2016     8.0
#
# [67 rows x 4 columns]

# %%
row_1 = df.iloc[0,:]
row_1
# Out:
# Movie     3 Idiots
# Genre       Comedy
# Year          2009
# Rating         8.4
# Name: 0, dtype: object

# %%
genre = df.iloc[3, 1]
genre
# Out:
# 'Sports'

# %%
first_3_row = df.iloc[0:3,0:]
first_3_row
# Out:
#       Movie   Genre  Year  Rating
# 0  3 Idiots  Comedy  2009     8.4
# 1    Dangal   Drama  2016     8.4
# 2        PK  Comedy  2014     8.1

# %%
last_2_rows = df.iloc[-2:,0:]
last_2_rows
# Out:
#          Movie    Genre  Year  Rating
# 65     Gravity   Sci-Fi  2013     7.7
# 66  La La Land  Musical  2016     8.0

# %%
znmd = df.loc[df["Movie"] == "Zindagi Na Milegi Dobara",:]
znmd
# Out:
#                        Movie  Genre  Year  Rating
# 13  Zindagi Na Milegi Dobara  Drama  2011     8.1
