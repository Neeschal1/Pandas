# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeschal1/Pandas/blob/main/CSV's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Reading CSV File

# %%
df = pd.read_csv("/content/drive/MyDrive/Learning_Pandas/readme.csv")
df
# Out:
#     ID     Language                Category  First_Appeared  \
# 0    1       Python            Data Science            1991
# 1    2   JavaScript         Web Development            1995
# 2    3         Java     Android Development            1995
# 3    4          C++        Game Development            1985
# 4    5            C     Systems Programming            1972
# 5    6           C#            Desktop Apps            2000
# 6    7            R    Statistical Analysis            1993
# 7    8          PHP   Server-Side Scripting            1994
# 8    9           Go    Cloud Infrastructure            2009
# 9   10         Rust     Systems Programming            2010
# 10  11        Swift         iOS Development            2014
# 11  12       Kotlin     Android Development            2011
# 12  13   TypeScript         Web Development            2012
# 13  14        Scala                Big Data            2004
# 14  15         Perl               Scripting            1987
# ...

# %% [markdown]
# # Terms that can be used while accessing data files:
# 1. head(): Accessing first 5 data

# %%
df.head()
# Out:
#    ID    Language             Category  First_Appeared            Creator  \
# 0   1      Python         Data Science            1991   Guido van Rossum
# 1   2  JavaScript      Web Development            1995       Brendan Eich
# 2   3        Java  Android Development            1995      James Gosling
# 3   4         C++     Game Development            1985  Bjarne Stroustrup
# 4   5           C  Systems Programming            1972     Dennis Ritchie
#
#    Popularity_Score Job_Demand  Average_Salary_USD  Lines_of_Code_Written
# 0                95       High              120000                 534234
# 1                92       High              115000                 654321
# 2                88       High              110000                 489000
# 3                80     Medium              108000                 432198
# 4                78     Medium              102000                 389123
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %% [markdown]
# 2. tail(): Accessing last 5 data

# %%
df.tail()
# Out:
#     ID  Language                Category  First_Appeared  \
# 45  46    Scheme  Functional Programming            1975
# 46  47   Scratch                Teaching            2003
# 47  48  VBScript               Scripting            1996
# 48  49      Logo                Teaching            1967
# 49  50      Lisp             AI Research            1958
#
#                                Creator  Popularity_Score Job_Demand  \
# 45  Guy L. Steele & Gerald Jay Sussman                44        Low
# 46                       MIT Media Lab                70     Medium
# 47                           Microsoft                43        Low
# 48                      Seymour Papert                40        Low
# 49                       John McCarthy                42        Low
#
#     Average_Salary_USD  Lines_of_Code_Written
# 45               85000                 117654
# 46               65000                 195432
# 47               83000                 116789
# ...

# %% [markdown]
# 3. For knowing the shape of the whole data (i. e. How many rows and columns are included inside the data, basically representing the shape of data in matrix's m x n format)

# %%
df.shape
# Out:
# (50, 9)

# %% [markdown]
# 4. For knowing the name of columns in the entire data

# %%
df.columns
# Out:
# Index(['ID', 'Language', 'Category', 'First_Appeared', 'Creator',
#        'Popularity_Score', 'Job_Demand', 'Average_Salary_USD',
#        'Lines_of_Code_Written'],
#       dtype='object')

# %% [markdown]
# # Other operations of datas

# %%
df[0:10:2] #Getting data from 0th to 9th index, jumping 1 data each
# Out:
#    ID Language              Category  First_Appeared  \
# 0   1   Python          Data Science            1991
# 2   3     Java   Android Development            1995
# 4   5        C   Systems Programming            1972
# 6   7        R  Statistical Analysis            1993
# 8   9       Go  Cloud Infrastructure            2009
#
#                          Creator  Popularity_Score Job_Demand  \
# 0               Guido van Rossum                95       High
# 2                  James Gosling                88       High
# 4                 Dennis Ritchie                78     Medium
# 6  Ross Ihaka & Robert Gentleman                72     Medium
# 8               Robert Griesemer                85       High
#
#    Average_Salary_USD  Lines_of_Code_Written
# 0              120000                 534234
# 2              110000                 489000
# 4              102000                 389123
# 6               99000                 215678
# ...

# %%
popular = df[df['Popularity_Score']>80]
popular
# Out:
#     ID    Language              Category  First_Appeared  \
# 0    1      Python          Data Science            1991
# 1    2  JavaScript       Web Development            1995
# 2    3        Java   Android Development            1995
# 5    6          C#          Desktop Apps            2000
# 8    9          Go  Cloud Infrastructure            2009
# 9   10        Rust   Systems Programming            2010
# 10  11       Swift       iOS Development            2014
# 11  12      Kotlin   Android Development            2011
# 12  13  TypeScript       Web Development            2012
# 15  16         SQL             Databases            1978
# 16  17        HTML       Web Development            1993
# 17  18         CSS           Web Styling            1996
#
#                               Creator  Popularity_Score Job_Demand  \
# 0                    Guido van Rossum                95       High
# 1                        Brendan Eich                92       High
# ...
